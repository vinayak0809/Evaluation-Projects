# %%
# Loading Important libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading datasets

# %%
df = pd.read_csv(r'C:\Users\apple\Downloads\New folder\HR Analytics Project.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# There are only 26 numerical columns and 9 categorical columns

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
# There are only 1470 entries in the dataset with 35 columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Defining Categorical features

# %%
df["Education"] = df['Education'].replace({1:'Below College', 2:'College', 3:'Bachelor', 4:'Master', 5:'Doctor'})

# %%
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].replace({1:'Low', 2:'Medium', 3:'High', 4:'Very High'})

# %%
df['JobInvolvement'] = df['JobInvolvement'].replace({1:'Low', 2:'Medium', 3:'High', 4:'Very High'})

# %%
df['JobSatisfaction'] = df['JobSatisfaction'].replace({1:'Low', 2:'Medium', 3:'High', 4:'Very High'})

# %%
df['PerformanceRating'] = df['PerformanceRating'].replace({1:'Low', 2:'Good', 3:'Excellent', 4:'Outstanding'})

# %%
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].replace({1:'Low', 2:'Medium', 3:'High', 4:'Very High'})

# %%
df['WorkLifeBalance'] = df['WorkLifeBalance'].replace({1:'Bad', 2:'Good', 3:'Better', 4:'Best'})

# %%
df.describe().T
# Out:
#                           count          mean          std     min      25%  \
# Age                      1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome         1470.0      9.192517     8.106864     1.0     2.00
# EmployeeCount            1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber           1470.0   1024.865306   602.024335     1.0   491.25
# HourlyRate               1470.0     65.891156    20.329428    30.0    48.00
# JobLevel                 1470.0      2.063946     1.106940     1.0     1.00
# MonthlyIncome            1470.0   6502.931293  4707.956783  1009.0  2911.00
# MonthlyRate              1470.0  14313.103401  7117.786044  2094.0  8047.00
# NumCompaniesWorked       1470.0      2.693197     2.498009     0.0     1.00
# PercentSalaryHike        1470.0     15.209524     3.659938    11.0    12.00
# ...

# %%
# Since EmployeeCount and StandardHours have standard deviation zero  which means it has same values so we can drop them

# %%
# Attribute Employee Number is unique for each employee so we can drop it

# %%
# There are no null values in the dataset

# %%
# As the age column suggest that the employee age is between 18 to 60 so there is no need for the column 'Over18'

# %%
df = df.drop(['EmployeeCount', 'StandardHours', 'EmployeeNumber'], axis = 1)

# %%
df = df.drop(['Over18'], axis = 1)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                 1        College  Life Sciences                  Medium
# 1                 8  Below College  Life Sciences                    High
# 2                 2        College          Other               Very High
# 3                 3         Master  Life Sciences               Very High
# 4                 2  Below College        Medical                     Low
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 31)

# %%
# descriptive analysis of categorical variables

# %%
df.describe(include = "O").T
# Out:
#                          count unique                     top  freq
# Attrition                 1470      2                      No  1233
# BusinessTravel            1470      3           Travel_Rarely  1043
# Department                1470      3  Research & Development   961
# Education                 1470      5                Bachelor   572
# EducationField            1470      6           Life Sciences   606
# EnvironmentSatisfaction   1470      4                    High   453
# Gender                    1470      2                    Male   882
# JobInvolvement            1470      4                    High   868
# JobRole                   1470      9         Sales Executive   326
# JobSatisfaction           1470      4               Very High   459
# MaritalStatus             1470      3                 Married   673
# OverTime                  1470      2                      No  1054
# PerformanceRating         1470      2               Excellent  1244
# ...

# %%
#Attrition and over time are highly biased towards 'No' category

# %%
#Business travel are highly biased towards 'Travel_Rarely' category

# %%
for column in df.columns:
    print(f'{column} : {df[column].unique()}')
    print("================================================================")
# Out:
# Age : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ...
# Attrition : ['Yes' 'No']
# ...
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ...
# DailyRate : [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
# ...

# %%
categorical_columns = []
for column in df.columns:
    if df[column].dtype == 'O' and len(df[column].unique()) <= 30:
        categorical_columns.append(column)
        print(f'{column} : {df[column].unique()}')
        print(f'No. of unique values: {(df[column].value_counts())}')
        print("================================================================")
# Out:
# Attrition : ['Yes' 'No']
# No. of unique values: Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ...
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# No. of unique values: BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ...
# Department : ['Sales' 'Research & Development' 'Human Resources']
# No. of unique values: Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ...
# Education : ['College' 'Below College' 'Master' 'Bachelor' 'Doctor']
# No. of unique values: Education
# Bachelor         572
# Master           398
# College          282
# Below College    170
# Doctor            48
# Name: count, dtype: int64
# ...
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# No. of unique values: EducationField
# Life Sciences       606
# ...

# %%
# Value set of the categorical attributes is complete are now easy to understand

# %%
# so now we don't need to do preprocessing for these attributes

# %%
# Visualising the Employee Attrition rate

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
attrition_rate = df.Attrition.value_counts()
sns.barplot(x = attrition_rate.index, y = attrition_rate)
plt.title('Employee Attrition Count')
# Out:
# Text(0.5, 1.0, 'Employee Attrition Count')

# %%
plt.subplot(1,2,2)
plt.pie(attrition_rate, labels = attrition_rate.index, autopct = '%.2f%%')
plt.title('Employee Attrition Rate')
plt.show()

# %%
# Employee attrition rate is ver low to 16.12%

# %%
# Analyzing Attrition rate by gender

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
gender_attrition = df.Gender.value_counts()
sns.barplot(x = gender_attrition.index, y = gender_attrition)
plt.title('Employee Attrition Count')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
# Male counts to 882 and female count to 588

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Employee Distribution by Gender')
plt.pie(gender_attrition, labels = gender_attrition.index, autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2b333f1d720>,
# ...
#  [Text(-0.33991877217145816, 1.046162142464278, 'Male'),
#   Text(0.3399188701202255, -1.0461621106387813, 'Female')],
#  [Text(-0.18541023936624987, 0.5706338958896061, '60.00%'),
#   Text(0.18541029279285026, -0.5706338785302443, '40.00%')])

# %%
plt.figure(figsize=(10,5))
new_df = df[df['Attrition'] == 'Yes']
value_2 = new_df['Gender'].value_counts()
value_1 = df['Gender'].value_counts()
attrition_rate = np.floor((value_2/value_1)*100)
sns.barplot(x = value_2.index, y = value_2.values)
plt.title('Employee Attrition Rate by Gender')
plt.show()

# %%
value_2.value_counts()
# Out:
# count
# 150    1
# 87     1
# Name: count, dtype: int64

# %%
# The number of male employees in a organisation accounts for a higher proportion than female employees by 20%

# %%
# Male employees are more likely to leave the organisation

# %%
# Analyzing employee attrition by Age

# %%
# Visualizing employee distribution by age

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(x = 'Age', data = df, hue = 'Attrition', kde = True)
plt.title('Employee Distribution by Age')
# Out:
# Text(0.5, 1.0, 'Employee Distribution by Age')

# %%
plt.subplot(1,2,2)
sns.boxplot(x = 'Attrition', y = 'Age', data = df)
plt.title('Employee Distribution by Age and Attrition')
plt.tight_layout()
plt.show()

# %%
# Most of the employees are in between the age of 30 to 40
# As the age incresases the attrition rate decreases
# From the boxplot we can observe that median age of employees who left the organisation is less than the employees who are working in the organisation

# %%
# Employees with young people are more likely to left the organisation than the elder employees

# %%
# Analyzing employee attrition by Business travel

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(x = 'BusinessTravel', data = df, hue = 'Attrition', kde = True)
plt.title('Employee Distribution by Business travel')
# Out:
# Text(0.5, 1.0, 'Employee Distribution by Business travel')

# %%
BusinessTravel_attrition = df.BusinessTravel.value_counts()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Employee Distribution by Business travel')
plt.pie(BusinessTravel_attrition, labels = BusinessTravel_attrition.index, autopct = '%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2b3357678e0>,
# ...
#  [Text(-0.6728966948858769, 0.8701781645224518, 'Travel_Rarely'),
#   Text(0.36441614894376395, -1.037882878936249, 'Travel_Frequently'),
#   Text(1.0439613016770868, -0.3466191001671471, 'Non-Travel')],
#  [Text(-0.36703456084684194, 0.4746426351940646, '70.95%'),
#   Text(0.19877244487841667, -0.5661179339652267, '18.84%'),
#   Text(0.5694334372784109, -0.18906496372753476, '10.20%')])

# %%
# Most of the employees travel rarely

# %%
#Highest employee attrition can be observed by those employees who Travels Frequently.
#Lowest employee attrition can be observed by those employees who are Non-Travel.

# %%
# Employee distribution by Education

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
value_1 = df['Education'].value_counts()
sns.barplot(x = value_1.index, y = value_1.values)
plt.title('Employee Distribution by Education')
plt.show()

# %%
# Employee Atrrition Rate by Education

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,2)
value_2 = new_df['Education'].value_counts()
sns.barplot(x = value_2.index, y = value_2.values)
plt.title('Employee Attrition Rate by Education')
plt.show()

# %%
#Most of the employees have completed their bachelor's and master's education

# %%
# Very few employees have completed their Doctarate degree as education

# %%
# We can see the decrease in attrition rate as the education qualification increases

# %%
# Employee distribution by EducationField

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
value_1 = df['EducationField'].value_counts()
sns.barplot(x = value_1.index, y = value_1.values)
plt.title('Employee Distribution by EducationField')
plt.show()

# %%
# Employee Atrrition Rate by EducationField

# %%
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
value_1 = new_df['EducationField'].value_counts()
sns.barplot(x = value_1.index, y = value_1.values)
plt.title('Employee Distribution by EducationField')
plt.show()

# %%
df.hist(figsize = (20,20), bins = 50, grid = True, layout = (4,4))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'HourlyRate'}>],
#        [<Axes: title={'center': 'JobLevel'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>],
#        [<Axes: title={'center': 'PercentSalaryHike'}>,
#         <Axes: title={'center': 'StockOptionLevel'}>,
#         <Axes: title={'center': 'TotalWorkingYears'}>,
#         <Axes: title={'center': 'TrainingTimesLastYear'}>],
#        [<Axes: title={'center': 'YearsAtCompany'}>,
#         <Axes: title={'center': 'YearsInCurrentRole'}>,
#         <Axes: title={'center': 'YearsSinceLastPromotion'}>,
#         <Axes: title={'center': 'YearsWithCurrManager'}>]], dtype=object)

# %%
from scipy import stats

# %%
num_cols = df.select_dtypes(np.number).columns

# %%
new_df = df.copy()
new_df['Attrition'] = df['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
f_scores = {}
p_values = {}
for col in num_cols:
    f_score, p_value = stats.f_oneway(new_df[col], new_df['Attrition'])
    
    f_scores[col] = f_score
    p_values[col] = p_value

# %%
# Visualize the  F-Score of ANNOVA TEST

# %%
# Visualize the f_scores and p_values
keys = list(f_scores.keys())
values = list(f_scores.values())
plt.figure(figsize=(10,10))
sns.barplot(x = keys, y = values)
plt.title('F-Scores')
plt.xticks(rotation = 90)


for index,value in enumerate(values):
    plt.text(index, value, int(value), ha = 'center', va = 'bottom',fontweight = 'black', size = 8)
plt.tight_layout()
plt.show()

# %%
test_df = pd.DataFrame({'Features':keys, 'F_scores':values})
test_df['P_values'] = [format(p,'.2f') for p in list(p_values.values())]
test_df
# Out:
#                    Features      F_scores P_values
# 0                       Age  23766.934042     0.00
# 1                 DailyRate   5811.796569     0.00
# 2          DistanceFromHome   1820.614585     0.00
# 3                HourlyRate  15362.122371     0.00
# 4                  JobLevel   3911.331585     0.00
# 5             MonthlyIncome   2804.459632     0.00
# 6               MonthlyRate   5944.089071     0.00
# 7        NumCompaniesWorked   1478.188633     0.00
# 8         PercentSalaryHike  24602.507947     0.00
# 9          StockOptionLevel    683.069576     0.00
# 10        TotalWorkingYears   2994.906310     0.00
# 11    TrainingTimesLastYear   5691.401732     0.00
# 12           YearsAtCompany   1829.442766     0.00
# 13       YearsInCurrentRole   1834.262264     0.00
# 14  YearsSinceLastPromotion    573.896430     0.00
# 15     YearsWithCurrManager   1793.291314     0.00

# %%
#The following features shows a strong association with attrition, as indicated by their high F-scores and very low p-values.

#Age
#DailyRate
#HourlyRate
#MonthlyIncome
#MonthlyRate
#NumCompaniesWorked
#PercentSalaryHike
#TotalWorkingYears
#TrainingTimesLastYear
#YearsAtCompany
#YearsWithCurrManag

# %%
#The following features doen't shows significant relationship with attrition because of their moderate F-scores and p-values.

#DistanceFromHome
#StockOptionLevel
#YearsInCurrentRole
#YearsSinceLastPromotion
#It is important for the organization to pay attention to the identified significant features and consider them when implementing strategies to reduce attrition rates.

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
# PERFORM CHI-SQUARE TEST

# %%
cat_cols = df.select_dtypes('object').columns.tolist()
cat_cols.remove('Attrition')

# %%
chi2_statistic = {}
p_values = {}

for col in cat_cols:
    contigency_table = pd.crosstab(df[col],df['Attrition'])
    chi2_, p_value,_,_ = chi2_contingency(contigency_table)
    chi2_statistic[col] = chi2_
    p_values[col] = p_value

# %%
#Visualizing the CHI_SQUARE STATISTICS VALUES

# %%
columns = list(chi2_statistic.keys())
values = list(chi2_statistic.values())

plt.figure(figsize=(10,10))
sns.barplot(x = columns, y = values)
plt.xticks(rotation = 90)
plt.title('Chi-Square Statistic values of Categorical Features')
for index,value in enumerate(values):
    plt.text(index, value, int(value), ha = 'center', va = 'bottom',fontweight = 'black', size = 8)
plt.show()

# %%
# COMPARING CHI^2 STATISTICS AND P-VALUES OF CHI^2 TEST

# %%
test_df = pd.DataFrame({'Features':columns, 'Chi_2_Statistic':values})
test_df['P_values'] = [format(p,'.2f') for p in list(p_values.values())]
test_df
# Out:
#                     Features  Chi_2_Statistic P_values
# 0             BusinessTravel        24.182414     0.00
# 1                 Department        10.796007     0.00
# 2                  Education         3.073961     0.55
# 3             EducationField        16.024674     0.01
# 4    EnvironmentSatisfaction        22.503881     0.00
# 5                     Gender         1.116967     0.29
# 6             JobInvolvement        28.492021     0.00
# 7                    JobRole        86.190254     0.00
# 8            JobSatisfaction        17.505077     0.00
# 9              MaritalStatus        46.163677     0.00
# 10                  OverTime        87.564294     0.00
# 11         PerformanceRating         0.000155     0.99
# 12  RelationshipSatisfaction         5.241068     0.15
# 13           WorkLifeBalance        16.325097     0.00

# %%
#The following features showed statistically significant associations with employee attrition:

#Department
#EducationField
#EnvironmentSatisfaction
#JobInvolvement
#JobLevel
#JobRole
#JobSatisfaction
#MaritalStatus
#OverTime
#WorkLifeBalance
#The following features did not show statistically significant associations with attrition.

#Gender
#Education
#PerformanceRating
#RelationshipSatisfaction
#It is important for the organization to pay attention to the identified significant features and consider them when implementing strategies to reduce attrition rates.

# %%
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['Attrition'] = label.fit_transform(df['Attrition'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   object
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   object
#  12  JobLevel                  1470 non-null   int64
# ...

# %%
# Data processing

# %%
dummy_var = [column for column in df.drop('Attrition', axis = 1).columns if df[column].nunique() < 20]
data = pd.get_dummies(df, columns = dummy_var, drop_first = True, dtype = 'uint')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Columns: 136 entries, Age to YearsWithCurrManager_17
# dtypes: int32(1), int64(8), uint32(127)
# memory usage: 827.0 KB

# %%
print(data.shape)
df_ = data.T.drop_duplicates().T
data.drop_duplicates(inplace = True)
print(data.shape)
# Out:
# (1470, 136)
# (1470, 136)

# %%
df = data.copy()

# %%
df.drop('Attrition', axis = 1,).corrwith(df.Attrition).sort_values().plot(kind = 'barh',figsize = (10,30))
# Out:
# <Axes: >

# %%
# Train and Test Dataset

# %%
x = df.drop('Attrition', axis = 1)

# %%
y = df.Attrition

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_standard = scaler.transform(x)

# %%
classifiers = [LogisticRegression(), RandomForestClassifier(), SVC(), DecisionTreeClassifier(), XGBClassifier()]
for classifier in classifiers:
    classifier_name = type(classifier).__name__
    print(f"Training {classifier_name},,,")
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f'{classifier_name} Accuracy:' ,accuracy)
    print(f'{classifier_name} Classification Report:')
    print(classification_report(y_test, y_pred))
# Out:
# Training LogisticRegression,,,
# LogisticRegression Accuracy: 0.8639455782312925
# LogisticRegression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       380
#            1       0.51      0.52      0.52        61
#
#     accuracy                           0.86       441
#    macro avg       0.72      0.72      0.72       441
# weighted avg       0.87      0.86      0.86       441
#
# Training RandomForestClassifier,,,
# RandomForestClassifier Accuracy: 0.873015873015873
# RandomForestClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       380
#            1       1.00      0.08      0.15        61
#
#     accuracy                           0.87       441
#    macro avg       0.94      0.54      0.54       441
# weighted avg       0.89      0.87      0.82       441
#
# Training SVC,,,
# ...

# %%
# It has been seen that SVM has achieved the highest accuracy of among the classifiers

# %%
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf','linear','poly']}

# %%
svc = SVC()

# %%
grid_search = GridSearchCV(estimator = svc, param_grid = param_grid, scoring = 'accuracy', cv = 5, verbose = 2, n_jobs = -1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'linear', 'poly']},
#              scoring='accuracy', verbose=2)

# %%
best_svc = grid_search.best_estimator_

# %%
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
best_svc_pred = best_svc.predict(x_test)
best_svc_accuracy = accuracy_score(y_test, best_svc_pred)
print(f'Best SVC Accuracy:', {best_svc_accuracy})
print("Best SVC Classification Report:")
print(classification_report(y_test, best_svc_pred))
# Out:
# Best SVC Accuracy: {0.8752834467120182}
# Best SVC Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       380
#            1       0.60      0.30      0.40        61
#
#     accuracy                           0.88       441
#    macro avg       0.75      0.63      0.66       441
# weighted avg       0.85      0.88      0.86       441

# %%
# Best SVC MODEL achieved an accuracy of approximately of 0.88 on the test set

# %%
# Save the trained model to a file

# %%
import pickle

# %%
with open('HR_ANALYTICS_PROJECT.pkl', 'wb') as f:
    pickle.dump(best_svc, f)
